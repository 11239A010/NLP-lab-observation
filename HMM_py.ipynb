# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A010/NLP-lab-observation/blob/main/HMM_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
from nltk.tag import hmm

warnings.filterwarnings("ignore")

train = [[('The','DT'),('dog','NN'),('barks','VBZ')],
         [('A','DT'),('cat','NN'),('meows','VBZ')]]

tagger = hmm.HiddenMarkovModelTrainer().train_supervised(train)
print(tagger.tag(['A','dog','meows']))
# Out:
# [('A', 'DT'), ('dog', 'NN'), ('meows', 'VBZ')]
