# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A010/NLP-lab-observation/blob/main/normalization_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('wordnet', quiet=True)

lem = WordNetLemmatizer()

text = "running runners ran easily fairer"
tokens = word_tokenize(text.lower())
norm = [lem.lemmatize(w) for w in tokens]

print("Original:", tokens)
print("Normalized:", norm)
# Out:
# Original: ['running', 'runners', 'ran', 'easily', 'fairer']
# Normalized: ['running', 'runner', 'ran', 'easily', 'fairer']
