# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A010/NLP-lab-observation/blob/main/spelling_correction_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob

# Sample text with spelling errors
text = "I havv goood speling."

# Create a TextBlob object
blob = TextBlob(text)

# Correct the spelling
corrected_text = blob.correct()

# Output the corrected text
print("Original:", text)
print("Corrected:", corrected_text)
# Out:
# Original: I havv goood speling.
# Corrected: I have good spelling.
