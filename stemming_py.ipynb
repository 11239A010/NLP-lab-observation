# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A010/NLP-lab-observation/blob/main/stemming_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download necessary NLTK models/data
nltk.download('punkt')
# Also download punkt_tab in case your version requires it
try:
    nltk.download('punkt_tab')
except Exception:
    pass

ps = PorterStemmer()

text = "running runner runs easily fairer"
tokens = word_tokenize(text.lower())

stemmed = [ps.stem(token) for token in tokens]
print("Original:", tokens)
print("Stemmed:", stemmed)
# Out:
# Original: ['running', 'runner', 'runs', 'easily', 'fairer']
# Stemmed: ['run', 'runner', 'run', 'easili', 'fairer']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
