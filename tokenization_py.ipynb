# %% [markdown]
# <a href="https://colab.research.google.com/github/11239A010/NLP-lab-observation/blob/main/tokenization_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tiktoken


encoding = tiktoken.get_encoding("cl100k_base")


text = "Hello, how are you?"


tokens = encoding.encode(text)

decoded_text = encoding.decode(tokens)


print("Original Text:", text)
print("Tokens:", tokens)
print("Decoded Text:", decoded_text)
print("Number of Tokens:", len(tokens))
# Out:
# Original Text: Hello, how are you?
# Tokens: [9906, 11, 1268, 527, 499, 30]
# Decoded Text: Hello, how are you?
# Number of Tokens: 6
